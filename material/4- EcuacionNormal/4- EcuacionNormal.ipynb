# %% [markdown]
# # Ecuación Normal

# %% [markdown]
# Suponemos el siguiente sistema de ecuaciones:
#
#
# $x+y+z=12$
#
# $2x-y+z=7$
#
# $x+2y-z=6$
#
#
# ¿Cuánto vale x,y,z?
# Podemos reescribir el problema de la siguiente manera:
#
#
#
# $\begin{pmatrix}1 & 1 &1\\2 & -1 & 1\\1 & 2 &-1\end{pmatrix} \cdot \begin{pmatrix}x \\y \\z\end{pmatrix} = \begin{pmatrix}12 \\7 \\6\end{pmatrix}$
#
#
#
# Si decimos que $A=\begin{pmatrix}1 & 1 &1\\2 & -1 & 1\\1 & 2 &-1\end{pmatrix}$
#
# , que $Y=\begin{pmatrix}12 \\7 \\6\end{pmatrix}$
#
# y que $X=\begin{pmatrix}x \\y \\z\end{pmatrix}$
#
# Nos queda entonces: $A \cdot X = Y$
#
# Lo que queremos es encontrar la matriz X, por lo que despejamos:
#
# 1. $A \cdot X= Y$
# 2. Se multiplica por el inverso de A, en ambos lados de la igualdad.
# 3. $(A^{-1}) A \cdot X= (A^{-1}) Y$
# 4. Como $A^{-1} \cdot A = I$, entonces: $I\cdot X=A^{-1}Y$
# 5. Como $I \cdot X=X$, entonces: $X=A^{-1}Y$

# %%
import numpy as np
import matplotlib.pyplot as plt
A = np.array([[1, 1, 1], [2, -1, 1], [1, 2, -1]])
Y = np.array([[12], [7], [6]])
print('A= ', A, sep='\n', end='\n\n')
print('Y= ', Y, sep='\n', end='\n\n')
X = np.linalg.inv(A).dot(Y)
print('X= ', X, sep='\n', end='\n\n')
# Out:
# A=
# [[ 1  1  1]
#  [ 2 -1  1]
#  [ 1  2 -1]]
#
# Y=
# [[12]
#  [ 7]
#  [ 6]]
#
# X=
# [[3.]
#  [4.]
#  [5.]]

# %% [markdown]
# # Ejercicios

# %% [markdown]
# Resuelve los siguientes sistemas de ecuaciones:
#
# $x-3y+2z=-3$
#
# $5x+6y-z=13$
#
# $4x-y+3z=8$

# %%
import numpy as np
import matplotlib.pyplot as plt
A = np.array([[1, -3, 2], [5, 6, -1], [4, -1, 3]])
Y = np.array([[-3], [13], [8]])
print('A= ', A, sep='\n', end='\n\n')
print('Y= ', Y, sep='\n', end='\n\n')
X = np.linalg.inv(A).dot(Y)
print('X= ', X, sep='\n', end='\n\n')
print('Y= ', A@X, sep='\n', end='\n\n')
# Out:
# A=
# [[ 1 -3  2]
#  [ 5  6 -1]
#  [ 4 -1  3]]
#
# Y=
# [[-3]
#  [13]
#  [ 8]]
#
# X=
# [[-2.]
#  [ 5.]
#  [ 7.]]
#
# Y=
# [[-3.]
#  [13.]
#  [ 8.]]

# %% [markdown]
# $6x+y-z=14$
#
# $4x+2y-z=13$
#
# $x+2y+4z=12$

# %%
import numpy as np
import matplotlib.pyplot as plt
A = np.array([[6, 1, -1], [4, 2, -1], [1, 2, 4]])
Y = np.array([[14], [13], [12]])
print('A= ', A, sep='\n', end='\n\n')
print('Y= ', Y, sep='\n', end='\n\n')
X = np.linalg.inv(A).dot(Y)
print('X= ', X, sep='\n', end='\n\n')
print('Y= ', A@X, sep='\n', end='\n\n')
# Out:
# A=
# [[ 6  1 -1]
#  [ 4  2 -1]
#  [ 1  2  4]]
#
# Y=
# [[14]
#  [13]
#  [12]]
#
# X=
# [[2.]
#  [3.]
#  [1.]]
#
# Y=
# [[14.]
#  [13.]
#  [12.]]

# %% [markdown]
# $2a+b-3c=7$
#
# $5a-4b+c=-19$
#
# $a-b-4c=4$

# %%
import numpy as np
import matplotlib.pyplot as plt
A=np.array([[2,1,-3],[5,-4,1],[1,-1,-4]])
Y=np.array([[7],[-19],[4]])
print('A= ',A,sep='\n',end='\n\n')
print('Y= ',Y,sep='\n',end='\n\n')
X= np.linalg.inv(A).dot(Y)
print('X= ',X,sep='\n',end='\n\n')
print('Y= ',A@X,sep='\n',end='\n\n')
# Out:
# A=
# [[ 2  1 -3]
#  [ 5 -4  1]
#  [ 1 -1 -4]]
#
# Y=
# [[  7]
#  [-19]
#  [  4]]
#
# X=
# [[-1.]
#  [ 3.]
#  [-2.]]
#
# Y=
# [[  7.]
#  [-19.]
#  [  4.]]

# %% [markdown]
# # Ecuación Normal Lineal

# %% [markdown]
# Los siguientes datos fueron obtenidos de un muestreo realizado en un sensor de nivel, y su correspondiente verificación manual del nivel:
#
#
# \begin{array}{|c|c|}
# \hline
# Salida\; Sensor&Nivel\; Real\; de\; Nivel\; en\; \%\\\hline
# A&Y\\\hline
# 868 &90\\\hline
# 830&85\\\hline
# 787&80\\\hline
# 755&75\\\hline
# 725&70\\\hline
# 675&65\\\hline
# 640&60\\\hline
# 610&55\\\hline
# 535&50\\\hline
# 485&45\\\hline
# 390&40\\\hline
# 360&35\\\hline
# 285&30\\\hline
# 240&25\\\hline
# 200&20\\\hline
# 160&15\\\hline
# 110&10\\\hline
# \end{array}
#
# ![sensorgas.png](attachment:sensorgas.png)
#
# Lo que buscamos es encontrar la ecuación que caracteriza al sensor, y además asumimos que es lineal, por lo que la ecuación lineal debe tener la siguiente estructura: $C+A \cdot X=Y$, que puede reescribirse como $x_0 +x_1 \cdot A=Y$, donde:
#
# 1. $x_0$ es una constante
# 2. A es el valor obtenido del sensor
# 3. $x_1$ es el coeficiente del valor obtenido del sensor
# 4. Y es el nivel real para esa salida $x_1$ del sensor
#
#
# De tal manera que la variable independiente es $X$ y la variable dependiente es $Y$
#
# Entonces, reescribimos la ecuación $A \cdot X = Y$ de la siguiente manera:
#
# $\begin{pmatrix} A \end{pmatrix} \cdot \begin{pmatrix}x_0\\ x_1 \end{pmatrix}=Y$
#
# Los valores para este ejemplo son:
#
#
# $A=\begin{pmatrix}
# 1&868\\
# 1&830\\
# 1&787\\
# 1&755\\
# 1&725\\
# 1&675\\
# 1&640\\
# 1&610\\
# 1&535\\
# 1&485\\
# 1&390\\
# 1&360\\
# 1&285\\
# 1&240\\
# 1&200\\
# 1&160\\
# 1&110\\
#  \end{pmatrix}, X=\begin{pmatrix} x_0\\x_1\end{pmatrix}, Y=\begin{pmatrix}
# 90\\
# 85\\
# 80\\
# 75\\
# 70\\
# 65\\
# 60\\
# 55\\
# 50\\
# 45\\
# 40\\
# 35\\
# 30\\
# 25\\
# 20\\
# 15\\
# 10\\
#  \end{pmatrix}$
#
# Lo que queremos es encontrar la matriz $X$, por lo que despejamos:
#
# 1. $A \cdot X= Y$
# 2. Se multiplica por el inverso de A, en ambos lados de la igualdad.
# 3. $(A^{-1}) A \cdot X= (A^{-1}) Y$
# 4. Sin embargo, no es posible obtener inversa de A, dado que A no es una matriz cuadrada; por lo que es necesario usar un truco matemático que nos permita realizar lo anterior.
# 5. Entonces, partiendo de lo siguiente: $A \cdot X= Y$
# 6. Podemos multiplicar ambos lados de la igualdad por un factor común.
# 7. $(A^T\cdot A)\cdot X= A^T\cdot Y$
# 8. Volvemos a multiplicar ambos lados de la igualdad por un factor común.
# 9. $(A^T\cdot A)^{-1}\cdot(A^T\cdot A)\cdot X=(A^T\cdot A)^{-1}\cdot A^T\cdot Y$
# 10. Lo que nos queda.
# 11. $I \cdot X=(A^T\cdot A)^{-1}\cdot A^T\cdot Y$
# 12. Lo que nos queda.
# 13. $X=(A^T\cdot A)^{-1}\cdot A^T\cdot Y$
#
#
# Lo anterior se conoce como método de $\textbf{Ecuación Normal}$, y es igual a:
#
# $X=(A^T\cdot A)^{-1}\cdot A^T\cdot Y$
#
# En Python es:
# $\textbf{import numpy as np}$
#
# $\textbf{X= np.linalg.inv(A.T.dot(A)).dot(A.T).dot(Y)}$

# %%
import numpy as np
import matplotlib.pyplot as plt
A=np.array([[1,868],[1,830],[1,787],[1,755],[1,725],[1,675],[1,640],[1,610],[1,535],[1,485],[1,390],[1,360],[1,285],[1,240],[1,200],[1,160],[1,110]])
Y=np.array([[90],[85],[80],[75],[70],[65],[60],[55],[50],[45],[40],[35],[30],[25],[20],[15],[10]])
print('A= ',A,sep='\n',end='\n\n')
print('Y= ',Y,sep='\n',end='\n\n')
X= np.linalg.inv(A.T.dot(A)).dot(A.T).dot(Y)
print('X= ',X,sep='\n',end='\n\n')
fig1 = plt.figure()
plt.plot(Y,A[:,1], 'r-')
plt.ylabel('salida sensor')
plt.xlabel('nivel real')
plt.title('Ecuacion Lineal')
Salida= A.dot(X)
plt.plot(Salida,A[:,1], 'b-')
# Out:
# A=
# [[  1 868]
#  [  1 830]
#  [  1 787]
#  [  1 755]
#  [  1 725]
#  [  1 675]
#  [  1 640]
#  [  1 610]
#  [  1 535]
#  [  1 485]
#  [  1 390]
#  [  1 360]
#  [  1 285]
#  [  1 240]
#  [  1 200]
#  [  1 160]
#  [  1 110]]
#
# Y=
# [[90]
#  [85]
#  [80]
#  [75]
#  [70]
#  [65]
#  [60]
#  [55]
#  [50]
#  [45]
#  [40]
#  [35]
#  [30]
#  [25]
#  [20]
#  [15]
#  [10]]
#
# X=
# [[-0.96834916]
#  [ 0.10011114]]

# %%
import numpy as np
import matplotlib.pyplot as plt
A=np.array([[1,868],[1,830],[1,787],[1,755],[1,725],[1,675],[1,640],[1,610],[1,535],[1,485],[1,390],[1,360],[1,285],[1,240],[1,200],[1,160],[1,110]])
Y=np.array([[90],[85],[80],[75],[70],[65],[60],[55],[50],[45],[40],[35],[30],[25],[20],[15],[10]])
print('A= ',A,sep='\n',end='\n\n')
print('Y= ',Y,sep='\n',end='\n\n')
X= np.linalg.inv(A.T.dot(A)).dot(A.T).dot(Y)
print('X= ',X,sep='\n',end='\n\n')
fig1 = plt.figure()
plt.plot(Y,A[:,1], 'r-')
plt.ylabel('salida sensor')
plt.xlabel('nivel real')
plt.title('Ecuacion Lineal')
Salida= A.dot(X)
plt.plot(Salida,A[:,1], 'b-')
# Out:
# A=
# [[  1 868]
#  [  1 830]
#  [  1 787]
#  [  1 755]
#  [  1 725]
#  [  1 675]
#  [  1 640]
#  [  1 610]
#  [  1 535]
#  [  1 485]
#  [  1 390]
#  [  1 360]
#  [  1 285]
#  [  1 240]
#  [  1 200]
#  [  1 160]
#  [  1 110]]
#
# Y=
# [[90]
#  [85]
#  [80]
#  [75]
#  [70]
#  [65]
#  [60]
#  [55]
#  [50]
#  [45]
#  [40]
#  [35]
#  [30]
#  [25]
#  [20]
#  [15]
#  [10]]
#
# X=
# [[-0.96834916]
#  [ 0.10011114]]

# %% [markdown]
# # Error medio de las diferencias al cuadrado (J)

# %% [markdown]
# El error medio, nos da $\frac{1}{2}$ de las diferencias al cuadrado promedio entre los datos reales (entrenamiento) y los valores calculados con los parámetros obtenidos con el método de la ecuación normal (hipótesis):
#
# $J=\frac{1}{2m}\sum_{i=1}^m \left(y'^{(i)} - y^{(i)} \right)^2$
#
#
# Del ejemplo que hemos estado usando, al hacer los cálculos, $X=\begin{pmatrix}x_0\\ x_1 \end{pmatrix}$, nos da $X=\begin{pmatrix}-0.96835\\0.10011 \end{pmatrix}$
#
# Cuando hacemos los cálculos con esta hipotética ecuación, obtenemos lo siguiente:
#
#
# \begin{array}{|c|c|c|}
# \hline
# Salida\; Sensor&Nivel\; Real\; de\; Nivel\; en\; \%&Valores\; Calculados \\
# \hline
# A&Y&Y'\\\hline
# 868 &90 &85.928\\\hline
# 830&85&82.124\\\hline
# 787&80&77.819\\\hline
# 755&75&74.616\\\hline
# 725&70&71.612\\\hline
# 675&65&66.607\\\hline
# 640&60&63.103\\\hline
# 610&55&60.099\\\hline
# 535&50&52.591\\\hline
# 485&45&47.586\\\hline
# 390&40&38.075\\\hline
# 360&35&35.072\\\hline
# 285&30&27.563\\\hline
# 240&25&23.058\\\hline
# 200&20&19.054\\\hline
# 160&15&15.049\\\hline
# 110&10&10.044\\\hline
# \end{array}
#
#
# Como vemos hay un error entre lo real y lo calculado, para medir el error se suele usar el cuadrado del error, para que al momento su sumar los errores no se cancelen entre sí, se puede hacer como muestra la siguiente tabla:
#
# \begin{array}{|c|c|c|c|c|}
# \hline
# Salida\; Sensor&Nivel\; Real\; de\; Nivel\; en\; \%&Valores\; Calculados &Error&Error^2\\\hline
# A&Y&Y'&Y'-Y&(Y'-Y)^2\\\hline
# 868.00& 90.00& 85.93& -4.07& 16.58\\\hline
# 830.00& 85.00& 82.12& -2.88&  8.27\\\hline
# 787.00& 80.00& 77.82& -2.18&  4.76\\\hline
# 755.00& 75.00& 74.62& -0.38&  0.15\\\hline
# 725.00& 70.00& 71.61&  1.61&  2.60\\\hline
# 675.00& 65.00& 66.61&  1.61&  2.58\\\hline
# 640.00& 60.00& 63.10&  3.10&  9.63\\\hline
# 610.00& 55.00& 60.10&  5.10& 26.00\\\hline
# 535.00& 50.00& 52.59&  2.59&  6.71\\\hline
# 485.00& 45.00& 47.59&  2.59&  6.69\\\hline
# 390.00& 40.00& 38.07& -1.93&  3.71\\\hline
# 360.00& 35.00& 35.07&  0.07&  0.01\\\hline
# 285.00& 30.00& 27.56& -2.44&  5.94\\\hline
# 240.00& 25.00& 23.06& -1.94&  3.77\\\hline
# 200.00& 20.00& 19.05& -0.95&  0.90\\\hline
# 160.00& 15.00& 15.05&  0.05&  0.00\\\hline
# 110.00& 10.00& 10.04&  0.04&  0.00\\\hline
# &&&suma&suma\\\hline
# &&&-0.01&98.3\\\hline
# \end{array}
#
#
# Por lo que el promedio del error cuadrático medio es:
#
# $J=\frac{1}{2m}\sum_{i=1}^m \left(y'^{(i)} - y^{(i)} \right)^2$
#
# $J=\frac{1}{2\cdot 17}(98.3)$
#
#
# $J=2.8911$

# %%
import numpy as np
import matplotlib.pyplot as plt
A=np.array([[1,868],[1,830],[1,787],[1,755],[1,725],[1,675],[1,640],[1,610],[1,535],[1,485],[1,390],[1,360],[1,285],[1,240],[1,200],[1,160],[1,110]])
Y=np.array([[90],[85],[80],[75],[70],[65],[60],[55],[50],[45],[40],[35],[30],[25],[20],[15],[10]])
#print('A= ',A,sep='\n',end='\n\n')
#print('Y= ',Y,sep='\n',end='\n\n')
X= np.linalg.inv(A.T.dot(A)).dot(A.T).dot(Y)
#print('X= ',X,sep='\n',end='\n\n')
#YP = A@X
print('J= ',np.sum(np.power(A@X-Y,2))/(2*Y.size),sep='\n',end='\n\n')
# Out:
# J=
# 2.8907410740454207

# %% [markdown]
# # Ecuaciones de segundo grado o de mayor grado

# %% [markdown]
# Como vemos en la gráfica, la ecuación lineal (de primer grado), no se adapta bien a los datos de entrenamiento, por lo que tenemos que incrementar el grado de la ecuación para ver si podemos modelar mejor a los datos de entrenamiento.
#
# De esta manera, por ejemplo para un tercer grado, quedaría así:
#
# $\begin{array}{|c|c|c|c|}
# \hline
# Salida\; Sensor& (Salida\; Sensor)^2&(Salida\; Sensor)^3&Nivel\; Real\; de\; Nivel\; en\; \%\\\hline
# A&A^2&A^3&Y\\\hline
#         868.00& 753424.00& 653972032.00&    90.00\\\hline
#         830.00& 688900.00& 571787000.00&    85.00\\\hline
#         787.00& 619369.00& 487443403.00&    80.00\\\hline
#         755.00& 570025.00& 430368875.00&    75.00\\\hline
#         725.00& 525625.00& 381078125.00&    70.00\\\hline
#         675.00& 455625.00& 307546875.00&    65.00\\\hline
#         640.00& 409600.00& 262144000.00&    60.00\\\hline
#         610.00& 372100.00& 226981000.00&    55.00\\\hline
#         535.00& 286225.00& 153130375.00&    50.00\\\hline
#         485.00& 235225.00& 114084125.00&    45.00\\\hline
#         390.00& 152100.00& 59319000.00&    40.00\\\hline
#         360.00& 129600.00& 46656000.00&    35.00\\\hline
#         285.00& 81225.00& 23149125.00&    30.00\\\hline
#         240.00& 57600.00& 13824000.00&    25.00\\\hline
#         200.00& 40000.00& 8000000.00&    20.00\\\hline
#         160.00& 25600.00& 4096000.00&    15.00\\\hline
#         110.00& 12100.00& 1331000.00&    10.00\\\hline
# \end{array}$
#
#
# Ahora la ecuación esperada es: $x_0 +x_1\cdot A+ x_2\cdot A^2 + x_3\cdot A^3=Y$
#
#
#
#
# $A=\begin{pmatrix}
#      1.00&   868.00& 753424.00& 653972032.00\\\hline
#      1.00&   830.00& 688900.00& 571787000.00\\\hline
#      1.00&   787.00& 619369.00& 487443403.00\\\hline
#      1.00&   755.00& 570025.00& 430368875.00\\\hline
#      1.00&   725.00& 525625.00& 381078125.00\\\hline
#      1.00&   675.00& 455625.00& 307546875.00\\\hline
#      1.00&   640.00& 409600.00& 262144000.00\\\hline
#      1.00&   610.00& 372100.00& 226981000.00\\\hline
#      1.00&   535.00& 286225.00& 153130375.00\\\hline
#      1.00&   485.00& 235225.00& 114084125.00\\\hline
#      1.00&   390.00& 152100.00& 59319000.00\\\hline
#      1.00&   360.00& 129600.00& 46656000.00\\\hline
#      1.00&   285.00& 81225.00& 23149125.00\\\hline
#      1.00&   240.00& 57600.00& 13824000.00\\\hline
#      1.00&   200.00& 40000.00& 8000000.00\\\hline
#      1.00&   160.00& 25600.00& 4096000.00\\\hline
#      1.00&   110.00& 12100.00& 1331000.00\\\hline
#  \end{pmatrix}, X=\begin{pmatrix} x_0\\x_1\\x_2\\x_3\end{pmatrix}, Y=\begin{pmatrix}
# 90\\
# 85\\
# 80\\
# 75\\
# 70\\
# 65\\
# 60\\
# 55\\
# 50\\
# 45\\
# 40\\
# 35\\
# 30\\
# 25\\
# 20\\
# 15\\
# 10\\
#  \end{pmatrix}$
#
#
#
# Calculando $X=(A^T\cdot A)^{-1}\cdot A^T\cdot Y$
#
# $X=\begin{pmatrix}
#    9.1182e-04\\
#    1.1938e-01\\
#   -9.7328e-05\\
#    9.2200e-08\\
#  \end{pmatrix}$

# %% [markdown]
# Ahora la ecuación esperada es: $x_0 +x_1\cdot A_1+ x_2\cdot A_2 + x_3\cdot A_3 + x_4 \cdot A_4=Y$

# %%
import numpy as np
import matplotlib.pyplot as plt
A=np.array([[1,868],[1,830],[1,787],[1,755],[1,725],[1,675],
            [1,640],[1,610],[1,535],[1,485],[1,390],[1,360],
            [1,285],[1,240],[1,200],[1,160],[1,110]])
Y=np.array([[90],[85],[80],[75],[70],[65],[60],[55],[50],
            [45],[40],[35],[30],[25],[20],[15],[10]])
(nrow,ncol)=A.shape

print('A= ',A,sep='\n',end='\n\n')
#print('A= ',B,sep='\n',end='\n\n')
#print('X= ',X,sep='\n',end='\n\n')




B=A
X= np.linalg.inv(B.T.dot(B)).dot(B.T).dot(Y)
fig1 = plt.figure()
plt.plot(Y,A[:,1], 'r-')
plt.ylabel('salida sensor')
plt.xlabel('nivel real')
plt.title('Ecuación de orden 1')
Salida= B.dot(X)
plt.plot(Salida,B[:,1], 'b-')
print(f"matriz A en ecuación de orden 1: \n{B}")
print('J= ',np.sum(np.power(B@X-Y,2))/(2*Y.size),sep='\n',end='\n\n')


B=np.zeros([nrow,ncol+1],int)
B[:,0:ncol]=A
B[:,ncol]=A[:,1]**2
X= np.linalg.inv(B.T.dot(B)).dot(B.T).dot(Y)
fig1 = plt.figure()
plt.plot(Y,A[:,1], 'r-')
plt.ylabel('salida sensor')
plt.xlabel('nivel real')
plt.title('Ecuación de orden 2')
Salida= B.dot(X)
plt.plot(Salida,B[:,1], 'b-')
print(f"matriz A en ecuación de orden 2: \n{B}")
print('J= ',np.sum(np.power(B@X-Y,2))/(2*Y.size),sep='\n',end='\n\n')


B=np.zeros([nrow,ncol+2],int)
B[:,0:ncol]=A
B[:,ncol]=A[:,1]**2
B[:,ncol+1]=A[:,1]**3
X= np.linalg.inv(B.T.dot(B)).dot(B.T).dot(Y)
fig1 = plt.figure()
plt.plot(Y,A[:,1], 'r-')
plt.ylabel('salida sensor')
plt.xlabel('nivel real')
plt.title('Ecuación de orden 3')
Salida= B.dot(X)
plt.plot(Salida,B[:,1], 'b-')
print(f"matriz A en ecuación de orden 3: \n{B}")
print('J= ',np.sum(np.power(B@X-Y,2))/(2*Y.size),sep='\n',end='\n\n')

B=np.zeros([nrow,ncol+3],int)
B[:,0:ncol]=A
B[:,ncol]=A[:,1]**2
B[:,ncol+1]=A[:,1]**3
B[:,ncol+2]=A[:,1]**4
X= np.linalg.inv(B.T.dot(B)).dot(B.T).dot(Y)
fig1 = plt.figure()
plt.plot(Y,A[:,1], 'r-')
plt.ylabel('salida sensor')
plt.xlabel('nivel real')
plt.title('Ecuación de orden 4')
Salida= B.dot(X)
plt.plot(Salida,B[:,1], 'b-')
print(f"matriz A en ecuación de orden 4: \n{B}")
print('J= ',np.sum(np.power(B@X-Y,2))/(2*Y.size),sep='\n',end='\n\n')


B=np.zeros([nrow,ncol+4],int)
B[:,0:ncol]=A
B[:,ncol]=A[:,1]**2
B[:,ncol+1]=A[:,1]**3
B[:,ncol+2]=A[:,1]**4
B[:,ncol+3]=A[:,1]**5
X= np.linalg.inv(B.T.dot(B)).dot(B.T).dot(Y)
fig1 = plt.figure()
plt.plot(Y,A[:,1], 'r-')
plt.ylabel('salida sensor')
plt.xlabel('nivel real')
plt.title('Ecuación de orden 5')
Salida= B.dot(X)
plt.plot(Salida,B[:,1], 'b-')
print(f"matriz A en ecuación de orden 5: \n{B}")
print('J= ',np.sum(np.power(B@X-Y,2))/(2*Y.size),sep='\n',end='\n\n')
# Out:
# A=
# [[  1 868]
#  [  1 830]
#  [  1 787]
#  [  1 755]
#  [  1 725]
#  [  1 675]
#  [  1 640]
#  [  1 610]
#  [  1 535]
#  [  1 485]
#  [  1 390]
#  [  1 360]
#  [  1 285]
#  [  1 240]
#  [  1 200]
#  [  1 160]
#  [  1 110]]
#
# matriz A en ecuación de orden 1:
# [[  1 868]
#  [  1 830]
#  [  1 787]
#  [  1 755]
#  [  1 725]
#  [  1 675]
#  [  1 640]
#  [  1 610]
#  [  1 535]
#  [  1 485]
#  [  1 390]
#  [  1 360]
#  [  1 285]
#  [  1 240]
#  [  1 200]
#  [  1 160]
#  [  1 110]]
# J=
# 2.8907410740454207
#
# matriz A en ecuación de orden 2:
# [[     1    868 753424]
#  [     1    830 688900]
#  [     1    787 619369]
#  [     1    755 570025]
#  [     1    725 525625]
#  [     1    675 455625]
#  [     1    640 409600]
#  [     1    610 372100]
#  [     1    535 286225]
#  [     1    485 235225]
#  [     1    390 152100]
#  [     1    360 129600]
#  [     1    285  81225]
#  [     1    240  57600]
#  [     1    200  40000]
#  [     1    160  25600]
#  [     1    110  12100]]
# J=
# ...

# %% [markdown]
# ## https://support.microsoft.com/es-es/office/funci%C3%B3n-estimacion-lineal-84d7d0d9-6e50-4101-977a-fa7abf772b6d

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


A=np.array([[1,1],[1,2],[1,3],[1,4],[1,5],[1,6]])
Y=np.array([[3100],[4500],[4400],[5400],[7500],[8100]])
datos = np.hstack((A[:,1:],Y)) #Horizontalmente apilado

df = pd.DataFrame(datos)
df.to_csv("microsoft2.csv",index=False, sep=',')

print('A= ',A,sep='\n',end='\n\n')
print('Y= ',Y,sep='\n',end='\n\n')
X= np.linalg.inv(A.T.dot(A)).dot(A.T).dot(Y)
print('X= ',X,sep='\n',end='\n\n')
fig1 = plt.figure()
plt.plot(A[:,1],Y, 'r-')
plt.ylabel('salida sensor')
plt.xlabel('nivel real')
plt.title('Ecuacion Lineal')
Salida= A.dot(X)
plt.plot(A[:,1],Salida, 'b-')
A=np.array([[1,9]])
Salida= A.dot(X)
plt.plot(A[:,1],Salida, 'g*')
print(f"si A={A}, entonces Y={Salida}")
# Out:
# A=
# [[1 1]
#  [1 2]
#  [1 3]
#  [1 4]
#  [1 5]
#  [1 6]]
#
# Y=
# [[3100]
#  [4500]
#  [4400]
#  [5400]
#  [7500]
#  [8100]]
#
# X=
# [[2000.]
#  [1000.]]
#
# si A=[[1 9]], entonces Y=[[11000.]]
