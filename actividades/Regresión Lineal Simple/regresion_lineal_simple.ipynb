# %% [markdown]
# # Regresión Lineal Simple

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.array([[1, 3100], [2, 4500], [3, 4400],
                [4, 5400], [5, 7500], [6, 8100]])

x = data[:, 0]
y = data[:, 1]

n = len(x)
a = (n * np.sum(x*y) - np.sum(x) * np.sum(y)) / \
    (n * np.sum(x**2) - (np.sum(x))**2)
b = (np.sum(y) - a * np.sum(x)) / n


def predict(x):
    return a * x + b


mes_9 = predict(9)

plt.scatter(x, y, color='blue', label='Datos reales')
plt.plot(x, predict(x), color='red', label='Línea de regresión')
plt.scatter(9, mes_9, color='green', s=100, label='Predicción mes 9')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.title('Regresión Lineal de Ventas')
plt.legend()
plt.grid(True)

print(f"Predicción de ventas para el mes 9: {mes_9:.2f}")

plt.show()
# Out:
# Predicción de ventas para el mes 9: 11000.00
